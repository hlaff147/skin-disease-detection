# %% [markdown]
# #### **Import Libs**

# %%
import pandas as pd
import numpy as np
import optuna
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### **Getting training && validation data**

# %%
table = pd.read_csv('./databases/dermatology.csv')

data = np.array(table)
# Remove a primeira coluna dos dados, que não contém informações relevantes para o modelo.
data = data[:, 1:]

labels = []
for line in range(data.shape[0]):
  if(labels.count(data[line, data.shape[1]-1])==0):
    labels.append(data[line, data.shape[1]-1])

scaler = StandardScaler()
# Extrai as classes dos dados e converte-as em variáveis dummy, usando a função pd.get_dummies do Pandas.
y = np.array(pd.get_dummies(data[:, data.shape[1]-1])).astype(np.float32)
# O resultado é um array binário para cada classe, indicando se uma amostra pertence ou não a essa classe.

# Escala os dados usando StandardScaler (garantir que todas as variáveis tenham a mesma ordem de grandeza)
X = (data[:, :(data.shape[1]-1)]).astype(np.float32)

scaler.fit(X) 
# Divide os dados em três subconjuntos de treinamento, validação e teste, usando a função train_test_split do Scikit-Learn. A divisão é feita na proporção de 60% para treinamento, 20% para validação e 20% para teste.
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25)
# Out:
# Conjuntos de treinamento e teste separados!

# %% [markdown]
# #### **Parameters selection**

# %%
def objective(trial):
    model = MLPClassifier(
        hidden_layer_sizes=(trial.suggest_int('hidden_layer_sizes', 10, 100),)*trial.suggest_int('n_layers', 1, 5),
        activation=trial.suggest_categorical('activation', ['logistic', 'tanh', 'relu']),
        alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
        solver=trial.suggest_categorical('solver', ['lbfgs', 'sgd', 'adam']),
        learning_rate=trial.suggest_categorical('learning_rate', ['constant', 'invscaling', 'adaptive']),
        max_iter=trial.suggest_int('max_iter', 100, 1000)
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)

    accuracy = accuracy_score(y_val, y_pred)

    return 1 - accuracy

# %%
n_trials = 150

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=n_trials)
# Out:
# [I 2023-04-18 23:18:20,795] A new study created in memory with name: no-name-16258938-1fbc-4459-a22e-83720212139f
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:21,506] Trial 0 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 14, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.024408255128290483, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 722}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:23,100] Trial 1 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 77, 'n_layers': 4, 'activation': 'tanh', 'alpha': 4.661658851364363e-05, 'solver': 'lbfgs', 'learning_rate': 'invscaling', 'max_iter': 921}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:23,937] Trial 2 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 94, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.8419021918183282e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 947}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:24,944] Trial 3 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 66, 'n_layers': 2, 'activation': 'tanh', 'alpha': 0.02777151927218459, 'solver': 'sgd', 'learning_rate': 'constant', 'max_iter': 863}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:25,350] Trial 4 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 89, 'n_layers': 3, 'activation': 'logistic', 'alpha': 0.00018717945134118767, 'solver': 'sgd', 'learning_rate': 'constant', 'max_iter': 721}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:25,858] Trial 5 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 25, 'n_layers': 5, 'activation': 'logistic', 'alpha': 0.00018181066435748967, 'solver': 'sgd', 'learning_rate': 'adaptive', 'max_iter': 358}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (421) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:26,263] Trial 6 finished with value: 0.547945205479452 and parameters: {'hidden_layer_sizes': 46, 'n_layers': 1, 'activation': 'logistic', 'alpha': 0.0058190426144209126, 'solver': 'sgd', 'learning_rate': 'adaptive', 'max_iter': 421}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:27,281] Trial 7 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 40, 'n_layers': 1, 'activation': 'logistic', 'alpha': 0.04242352199155596, 'solver': 'adam', 'learning_rate': 'adaptive', 'max_iter': 986}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (860) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:28,226] Trial 8 finished with value: 0.5342465753424658 and parameters: {'hidden_layer_sizes': 53, 'n_layers': 1, 'activation': 'logistic', 'alpha': 0.0190920553640315, 'solver': 'sgd', 'learning_rate': 'adaptive', 'max_iter': 860}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (348) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:30,510] Trial 9 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 91, 'n_layers': 3, 'activation': 'logistic', 'alpha': 0.006805392427584019, 'solver': 'sgd', 'learning_rate': 'invscaling', 'max_iter': 348}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:30,910] Trial 10 finished with value: 0.17808219178082196 and parameters: {'hidden_layer_sizes': 10, 'n_layers': 4, 'activation': 'relu', 'alpha': 0.003091452865421169, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 611}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (128) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:31,408] Trial 11 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 99, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.0013057526064079e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 128}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:31,665] Trial 12 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 31, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.08752486590881481, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 184}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (124) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:31,980] Trial 13 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 68, 'n_layers': 4, 'activation': 'tanh', 'alpha': 1.3138752420876857e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 124}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:32,549] Trial 14 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 11, 'n_layers': 5, 'activation': 'relu', 'alpha': 0.0009706903679845268, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 674}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:34,727] Trial 15 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 77, 'n_layers': 4, 'activation': 'tanh', 'alpha': 0.0008023152617462278, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 544}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:35,521] Trial 16 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 24, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.160216050341262e-05, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 754}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:36,676] Trial 17 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 100, 'n_layers': 2, 'activation': 'tanh', 'alpha': 0.00035496980741057645, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 506}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:37,795] Trial 18 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 66, 'n_layers': 3, 'activation': 'relu', 'alpha': 0.0020649872480799558, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 229}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:38,853] Trial 19 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 39, 'n_layers': 4, 'activation': 'tanh', 'alpha': 6.872319027357744e-05, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 789}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (266) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:39,549] Trial 20 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 58, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.00042395025216259173, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 266}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:39,675] Trial 21 finished with value: 0.3287671232876712 and parameters: {'hidden_layer_sizes': 25, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.07453018971701299, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 101}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:40,034] Trial 22 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 33, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.07666929808490501, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 221}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:40,175] Trial 23 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 20, 'n_layers': 4, 'activation': 'tanh', 'alpha': 0.011914023842111758, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 164}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:40,618] Trial 24 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 18, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.09212134062533153, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 463}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:41,419] Trial 25 finished with value: 0.06849315068493156 and parameters: {'hidden_layer_sizes': 33, 'n_layers': 4, 'activation': 'relu', 'alpha': 0.03148700232740008, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 619}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:41,846] Trial 26 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 33, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.01461387795740791, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 286}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (156) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:41,961] Trial 27 finished with value: 0.20547945205479456 and parameters: {'hidden_layer_sizes': 16, 'n_layers': 2, 'activation': 'tanh', 'alpha': 0.054346083757584276, 'solver': 'adam', 'learning_rate': 'adaptive', 'max_iter': 156}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:43,146] Trial 28 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 49, 'n_layers': 4, 'activation': 'tanh', 'alpha': 0.027180553361603247, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 360}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:46,471] Trial 29 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 80, 'n_layers': 4, 'activation': 'tanh', 'alpha': 0.0020010375682654033, 'solver': 'lbfgs', 'learning_rate': 'invscaling', 'max_iter': 611}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:46,983] Trial 30 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 60, 'n_layers': 5, 'activation': 'relu', 'alpha': 0.010078806810290667, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 205}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:47,891] Trial 31 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 42, 'n_layers': 4, 'activation': 'tanh', 'alpha': 4.007143486878363e-05, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 793}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:48,992] Trial 32 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 38, 'n_layers': 5, 'activation': 'tanh', 'alpha': 6.334828260744315e-05, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 834}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:49,595] Trial 33 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 30, 'n_layers': 3, 'activation': 'tanh', 'alpha': 2.328457159267511e-05, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 707}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:50,549] Trial 34 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 47, 'n_layers': 5, 'activation': 'tanh', 'alpha': 6.512394736387994e-05, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 924}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:51,475] Trial 35 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 83, 'n_layers': 4, 'activation': 'tanh', 'alpha': 2.0815903854795394e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 783}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:52,509] Trial 36 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 28, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.00011278214208357668, 'solver': 'lbfgs', 'learning_rate': 'invscaling', 'max_iter': 683}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (897) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:53,428] Trial 37 finished with value: 0.31506849315068497 and parameters: {'hidden_layer_sizes': 16, 'n_layers': 5, 'activation': 'tanh', 'alpha': 3.876381749881466e-05, 'solver': 'sgd', 'learning_rate': 'constant', 'max_iter': 897}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:53,731] Trial 38 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 38, 'n_layers': 4, 'activation': 'logistic', 'alpha': 1.0472656325616441e-05, 'solver': 'adam', 'learning_rate': 'adaptive', 'max_iter': 820}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (993) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:54,691] Trial 39 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 22, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.05058989169495538, 'solver': 'sgd', 'learning_rate': 'adaptive', 'max_iter': 993}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:18:55,039] Trial 40 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 52, 'n_layers': 4, 'activation': 'logistic', 'alpha': 0.02617204884144399, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 405}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:55,497] Trial 41 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 18, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.09325054070187155, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 465}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:55,717] Trial 42 finished with value: 0.28767123287671237 and parameters: {'hidden_layer_sizes': 11, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.09401011725080097, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 285}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:56,614] Trial 43 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 28, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.041393357928231504, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 643}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:58,638] Trial 44 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 43, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.020953615302404593, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 549}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:18:59,293] Trial 45 finished with value: 0.136986301369863 and parameters: {'hidden_layer_sizes': 18, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.06338494116809655, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 726}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (330) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:18:59,582] Trial 46 finished with value: 0.5616438356164384 and parameters: {'hidden_layer_sizes': 13, 'n_layers': 4, 'activation': 'tanh', 'alpha': 0.048128319687904285, 'solver': 'sgd', 'learning_rate': 'constant', 'max_iter': 330}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:19:02,955] Trial 47 finished with value: 0.1095890410958904 and parameters: {'hidden_layer_sizes': 72, 'n_layers': 3, 'activation': 'logistic', 'alpha': 1.8506082750366955e-05, 'solver': 'lbfgs', 'learning_rate': 'invscaling', 'max_iter': 456}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:03,538] Trial 48 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 98, 'n_layers': 5, 'activation': 'relu', 'alpha': 1.598741231625354e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 579}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:19:03,723] Trial 49 finished with value: 0.15068493150684936 and parameters: {'hidden_layer_sizes': 23, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.03524474750208786, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 158}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (865) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:19:04,347] Trial 50 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 14, 'n_layers': 2, 'activation': 'tanh', 'alpha': 0.016005494598500855, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 865}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:05,364] Trial 51 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 93, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.960552248136664e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 950}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:05,911] Trial 52 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 87, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.710867034014424e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 943}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:06,835] Trial 53 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 97, 'n_layers': 4, 'activation': 'tanh', 'alpha': 1.5343430773920605e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 963}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:07,861] Trial 54 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 90, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.0473683538656106e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 888}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:19:10,147] Trial 55 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 96, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.9814122759704372e-05, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 748}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (190) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:19:10,704] Trial 56 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 94, 'n_layers': 3, 'activation': 'relu', 'alpha': 0.06177589653160908, 'solver': 'adam', 'learning_rate': 'adaptive', 'max_iter': 190}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# ...
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (689) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:21,254] Trial 129 finished with value: 0.1917808219178082 and parameters: {'hidden_layer_sizes': 33, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.4589685424984084e-05, 'solver': 'sgd', 'learning_rate': 'constant', 'max_iter': 689}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:21,749] Trial 130 finished with value: 1.0 and parameters: {'hidden_layer_sizes': 92, 'n_layers': 5, 'activation': 'logistic', 'alpha': 0.0002900395079322733, 'solver': 'adam', 'learning_rate': 'adaptive', 'max_iter': 663}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (728) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:22,486] Trial 131 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 20, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.036231095522070815, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 728}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (699) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:23,199] Trial 132 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 21, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.04565442706109445, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 699}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (116) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:23,343] Trial 133 finished with value: 0.452054794520548 and parameters: {'hidden_layer_sizes': 13, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.0599433952101949, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 116}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (801) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:24,143] Trial 134 finished with value: 0.0547945205479452 and parameters: {'hidden_layer_sizes': 16, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.02687792579941993, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 801}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (247) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:24,767] Trial 135 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 39, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.043979382785419685, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 247}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:20:25,542] Trial 136 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 23, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.07498499512146273, 'solver': 'lbfgs', 'learning_rate': 'invscaling', 'max_iter': 762}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:26,498] Trial 137 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 97, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.1818114619996872e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 905}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:27,408] Trial 138 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 89, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.009641234828558705, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 925}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:29,345] Trial 139 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 94, 'n_layers': 5, 'activation': 'tanh', 'alpha': 7.438999018990576e-05, 'solver': 'lbfgs', 'learning_rate': 'constant', 'max_iter': 627}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:29,645] Trial 140 finished with value: 0.04109589041095896 and parameters: {'hidden_layer_sizes': 36, 'n_layers': 4, 'activation': 'relu', 'alpha': 0.08488984379471534, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 571}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:30,425] Trial 141 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 68, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.056622621949052e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 973}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:32,422] Trial 142 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 76, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.06096687670093989, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 965}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:33,468] Trial 143 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 18, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.8013299869795446e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 944}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:34,518] Trial 144 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 96, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.0015745150007278e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 982}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (208) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:35,332] Trial 145 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 79, 'n_layers': 5, 'activation': 'tanh', 'alpha': 3.8588649077180374e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 208}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (308) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2023-04-18 23:20:36,086] Trial 146 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 59, 'n_layers': 5, 'activation': 'tanh', 'alpha': 2.4590418894666143e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 308}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# d:\MiniConda\envs\DataScience\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:541: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [I 2023-04-18 23:20:36,632] Trial 147 finished with value: 0.3013698630136986 and parameters: {'hidden_layer_sizes': 11, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.4630797734554711e-05, 'solver': 'lbfgs', 'learning_rate': 'adaptive', 'max_iter': 707}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:39,063] Trial 148 finished with value: 0.013698630136986356 and parameters: {'hidden_layer_sizes': 92, 'n_layers': 5, 'activation': 'tanh', 'alpha': 0.09761512308028966, 'solver': 'adam', 'learning_rate': 'invscaling', 'max_iter': 885}. Best is trial 0 with value: 0.013698630136986356.
# C:\Users\betin\AppData\Local\Temp\ipykernel_17216\3818634782.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   alpha=trial.suggest_loguniform('alpha', 1e-5, 1e-1),
# [I 2023-04-18 23:20:39,960] Trial 149 finished with value: 0.0273972602739726 and parameters: {'hidden_layer_sizes': 72, 'n_layers': 5, 'activation': 'tanh', 'alpha': 1.9800421959462336e-05, 'solver': 'adam', 'learning_rate': 'constant', 'max_iter': 389}. Best is trial 0 with value: 0.013698630136986356.

# %% [markdown]
# #### **Saving study**

# %%
save_path = './optuna_studies/mlp_study.pkl'

joblib.dump(study, save_path)
# Out:
# ['./optuna_studies/mlp_study.pkl']
